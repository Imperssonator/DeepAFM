# %%
import nanoscope
from PIL import Image
from astropy import units as u
import matplotlib.pyplot as plt
import sys
sys.path.append('/Users/Imperssonator/CC/DeepAFM/PyFiber/')
import fastaniso

# %matplotlib notebook

# %%
test_file = '/Users/Imperssonator/CC/DeepAFM/Data/capture/Bailey/8_3_07a.001'

# %%
raw = nanoscope.read(test_file)
raw.phase.process()
raw.phase.flatten(order=3)

# %%
pixels=raw.phase.colorize()

# %%
h_img = Image.fromarray(pixels)
gray=h_img.convert('L')
# %matplotlib notebook
plt.imshow(gray,cmap='gray')
# Out:
# <img src="data:image/png;base64,...">
